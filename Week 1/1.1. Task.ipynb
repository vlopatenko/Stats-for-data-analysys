# %%
import pandas as pd
import scipy.stats as st
from statsmodels.stats.weightstats import _tconfint_generic

# %% [markdown]
# **Для 61 большого города в Англии и Уэльсе известны средняя годовая смертность на 100000 населения (по данным 1958–1964) и концентрация кальция в питьевой воде (в частях на миллион). Чем выше концентрация кальция, тем жёстче вода. Города дополнительно поделены на северные и южные.
# Постройте 95% доверительный интервал для средней годовой смертности в больших городах. Чему равна его нижняя граница? Округлите ответ до 4 знаков после десятичной точки.**

# %%
data = pd.read_csv('/kaggle/input/water.txt', sep='\t')
data

# %%
data.info()

# %%
print("95% confidence interval for mortality", [round(x, 4) for x in _tconfint_generic(data.mortality.mean(), 
                                                                                        data.mortality.std() / np.sqrt(data.shape[0]), 
                                                                                        data.shape[0] - 1, 
                                                                                        0.05, 'two-sided')])

# %% [markdown]
# **На данных из предыдущего вопроса постройте 95% доверительный интервал для средней годовой смертности по всем южным городам. Чему равна его верхняя граница? Округлите ответ до 4 знаков после десятичной точки.**

# %%
south_data = data[data.location == 'South']
print("95% confidence interval for mortality in South region", [round(x, 4) for x in _tconfint_generic(south_data.mortality.mean(), 
                                                                         south_data.mortality.std() / np.sqrt(south_data.shape[0]), 
                                                                                                        south_data.shape[0] - 1, 
                                                                                                        0.05, 'two-sided')])

# %% [markdown]
# **На тех же данных постройте 95% доверительный интервал для средней годовой смертности по всем северным городам. Пересекается ли этот интервал с предыдущим?**

# %%
north_data = data[data.location == 'North']
print("95% confidence interval for mortality in North region", [round(x, 4) for x in _tconfint_generic(north_data.mortality.mean(), 
                                                                         north_data.mortality.std() / np.sqrt(north_data.shape[0]), 
                                                                                                        north_data.shape[0] - 1, 
                                                                                                        0.05, 'two-sided')])

# %% [markdown]
# **Нет, не пересекается**

# %% [markdown]
# **Пересекаются ли 95% доверительные интервалы для средней жёсткости воды в северных и южных городах?**

# %%
print("95% confidence interval for water hardness in South region", [round(x, 4) for x in _tconfint_generic(south_data.hardness.mean(), 
                                                                              south_data.hardness.std() / np.sqrt(south_data.shape[0]), 
                                                                                                             south_data.shape[0] - 1, 
                                                                                                             0.05, 'two-sided')])

# %%
print("95%% confidence interval for water hardness in North region", [round(x, 4) for x in _tconfint_generic(north_data.hardness.mean(), 
                                                                               north_data.hardness.std() / np.sqrt(north_data.shape[0]), 
                                                                                                             north_data.shape[0] - 1, 
                                                                                                             0.05, 'two-sided')])

# %% [markdown]
# **Нет, не пересекаются**

# %% [markdown]
# **Вспомним формулу доверительного интервала для среднего нормально распределённой случайной величины с дисперсией σ.
# При σ=1 какой нужен объём выборки, чтобы на уровне доверия 95% оценить среднее с точностью ±0.1?**

# %%
np.ceil(100 * st.norm.ppf(.025) ** 2)
